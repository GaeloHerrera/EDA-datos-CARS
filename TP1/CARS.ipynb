# %% [markdown]
# <a href="https://colab.research.google.com/github/GaeloHerrera/EDA-datos-CARS/blob/main/TP1/CARS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# %%
data = pd.read_csv("COPY_CARS.csv")

# %%
data.shape
# Out:
# (428, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    int64
#  10  MPG_City     428 non-null    int64
#  11  MPG_Highway  428 non-null    int64
#  12  Weight       428 non-null    int64
#  13  Wheelbase    428 non-null    int64
#  14  Length       428 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 50.3+ KB

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data["Make"].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
marca = data["Make"].value_counts()
marca
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64

# %%
marca = data.query("Make == 'Toyota'")
marca
# Out:
#        Make                       Model    Type Origin DriveTrain     MSRP  \
# 373  Toyota    Prius 4dr (gas/electric)  Hybrid   Asia      Front  $20,510
# 374  Toyota                 Sequoia SR5     SUV   Asia        All  $35,695
# 375  Toyota              4Runner SR5 V6     SUV   Asia      Front  $27,710
# 376  Toyota               Highlander V6     SUV   Asia        All  $27,930
# 377  Toyota                Land Cruiser     SUV   Asia        All  $54,765
# 378  Toyota                        RAV4     SUV   Asia        All  $20,290
# 379  Toyota              Corolla CE 4dr   Sedan   Asia      Front  $14,085
# 380  Toyota               Corolla S 4dr   Sedan   Asia      Front  $15,030
# 381  Toyota              Corolla LE 4dr   Sedan   Asia      Front  $15,295
# 382  Toyota             Echo 2dr manual   Sedan   Asia      Front  $10,760
# 383  Toyota               Echo 2dr auto   Sedan   Asia      Front  $11,560
# ...

# %%
data[data["Make"].isin(["Toyota", "Dodge"])]
# Out:
#        Make                         Model    Type Origin DriveTrain     MSRP  \
# 105   Dodge                   Durango SLT     SUV    USA        All  $32,235
# 106   Dodge                   Neon SE 4dr   Sedan    USA      Front  $13,670
# 107   Dodge                  Neon SXT 4dr   Sedan    USA      Front  $15,040
# 108   Dodge               Intrepid SE 4dr   Sedan    USA      Front  $22,035
# 109   Dodge               Stratus SXT 4dr   Sedan    USA      Front  $18,820
# 110   Dodge                Stratus SE 4dr   Sedan    USA      Front  $20,220
# 111   Dodge               Intrepid ES 4dr   Sedan    USA      Front  $24,885
# 112   Dodge                    Caravan SE   Sedan    USA      Front  $21,795
# 113   Dodge             Grand Caravan SXT   Sedan    USA        All  $32,660
# 114   Dodge  Viper SRT-10 convertible 2dr  Sports    USA       Rear  $81,795
# 115   Dodge            Dakota Regular Cab   Truck    USA       Rear  $17,630
# ...

# %%
data["Origin"].unique()
data["Origin"].value_counts()
# Out:
# Origin
# Asia      158
# USA       147
# Europe    123
# Name: count, dtype: int64

# %%
data[["Make","Origin"]].value_counts()
# Out:
# Make           Origin
# Toyota         Asia      28
# Chevrolet      USA       27
# Mercedes-Benz  Europe    26
# Ford           USA       23
# BMW            Europe    20
# Audi           Europe    19
# Honda          Asia      17
# Nissan         Asia      17
# Volkswagen     Europe    15
# Chrysler       USA       15
# Dodge          USA       13
# Mitsubishi     Asia      13
# Volvo          Europe    12
# Jaguar         Europe    12
# Hyundai        Asia      12
# Subaru         Asia      11
# Pontiac        USA       11
# Mazda          Asia      11
# Lexus          Asia      11
# Kia            Asia      11
# Buick          USA        9
# Mercury        USA        9
# Lincoln        USA        9
# Saturn         USA        8
# Cadillac       USA        8
# Suzuki         Asia       8
# Infiniti       Asia       8
# GMC            USA        8
# Acura          Asia       7
# Porsche        Europe     7
# Saab           Europe     7
# Land Rover     Europe     3
# ...

# %%
data["Horsepower"].max()
data["Horsepower"].min()
# Out:
# 73

# %%
data[data["Horsepower"] == 500]
# Out:
#       Make                         Model    Type Origin DriveTrain     MSRP  \
# 114  Dodge  Viper SRT-10 convertible 2dr  Sports    USA       Rear  $81,795
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 114  $74,451         8.3       10.0         500        12           20
#
#      Weight  Wheelbase  Length
# 114    3410         99     176

# %%
data["Cylinders"].value_counts()
# Out:
# Cylinders
# 6.0     190
# 4.0     136
# 8.0      87
# 5.0       7
# 12.0      3
# 10.0      2
# 3.0       1
# Name: count, dtype: int64

# %%
data[(data["Make"]=="Audi") & (data["Horsepower"]>=200)]
# Out:
#     Make                             Model    Type  Origin DriveTrain  \
# 9   Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10  Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# 11  Audi           A4 3.0 Quattro 4dr auto   Sedan  Europe        All
# 12  Audi                        A6 3.0 4dr   Sedan  Europe      Front
# 13  Audi                A6 3.0 Quattro 4dr   Sedan  Europe        All
# 14  Audi            A4 3.0 convertible 2dr   Sedan  Europe      Front
# 15  Audi    A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 16  Audi          A6 2.7 Turbo Quattro 4dr   Sedan  Europe        All
# 17  Audi                A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18  Audi                  A8 L Quattro 4dr   Sedan  Europe        All
# 19  Audi                    S4 Quattro 4dr   Sedan  Europe        All
# 20  Audi                          RS 6 4dr  Sports  Europe      Front
# ...

# %%
audi = data.query("Make == 'Audi'")
audi1 = audi.count()
audi1
# Out:
# Make           19
# Model          19
# Type           19
# Origin         19
# DriveTrain     19
# MSRP           19
# Invoice        19
# EngineSize     19
# Cylinders      19
# Horsepower     19
# MPG_City       19
# MPG_Highway    19
# Weight         19
# Wheelbase      19
# Length         19
# dtype: int64

# %%
 data["Type"].value_counts()
 # 1) ES MÁS ABUNDANTDE LA CARROCERÍA DE SEDAN #
# Out:
# Type
# Sedan     262
# SUV        60
# Sports     49
# Wagon      30
# Truck      24
# Hybrid      3
# Name: count, dtype: int64

# %%
## 2) CROSSTAB, NO SE USAN CAMIONETAS EN EUROPA
crosstab = pd.crosstab(data["Type"], data["Origin"])
crosstab
# Out:
# Origin  Asia  Europe  USA
# Type
# Hybrid     3       0    0
# SUV       25      10   25
# Sedan     94      78   90
# Sports    17      23    9
# Truck      8       0   16
# Wagon     11      12    7

# %%
## 3) TIPO DE AJTO CON MENOR PESO
data[["Type", "Weight"]]
data["Weight"].min()  # El menor peso es 1850 ##
data[data["Weight"] == 1850]  ## POR LO QUE  EL TIPO HYBRID ES EL DE MENOR PESO ##
# Out:
#       Make                       Model    Type Origin DriveTrain     MSRP  \
# 150  Honda  Insight 2dr (gas/electric)  Hybrid   Asia      Front  $19,110
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 150  $17,911         2.0        3.0          73        60           66
#
#      Weight  Wheelbase  Length
# 150    1850         95     155

# %%
## 4) MARCAS QUE ELABORAN CARROS HÍBRIDOS, Y TENEMOS QUE 2 HONDA Y 1 YOYOTA ##
data[data["Type"] == "Hybrid"]
# Out:
#        Make                                   Model    Type Origin DriveTrain  \
# 149   Honda  Civic Hybrid 4dr manual (gas/electric)  Hybrid   Asia      Front
# 150   Honda              Insight 2dr (gas/electric)  Hybrid   Asia      Front
# 373  Toyota                Prius 4dr (gas/electric)  Hybrid   Asia      Front
#
#         MSRP  Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 149  $20,140  $18,451         1.4        4.0          93        46
# 150  $19,110  $17,911         2.0        3.0          73        60
# 373  $20,510  $18,926         1.5        4.0         110        59
#
#      MPG_Highway  Weight  Wheelbase  Length
# 149           51    2732        103     175
# 150           66    1850         95     155
# 373           51    2890        106     175

# %%
## 5) CREAR UNA TABLA CON MODELO MDX
data["Model"].value_counts()
data[data["Model"] == "MDX"]
# Out:
#     Make Model Type Origin DriveTrain     MSRP  Invoice  EngineSize  \
# 0  Acura   MDX  SUV   Asia        All  $36,945  $33,337         3.5
#
#    Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0        6.0         265        17           23    4451        106     189

# %%
data["Horsepower"].min()
# Out:
# 73

# %%
## 6) ¿CUÁLES SON LOS 3 MODELOS DE AUTO CON MAYOR CABALLOS DE FUERZA ?
data.sort_values(by = "Horsepower", ascending = False).head(3)
# Out:
#               Make                         Model    Type  Origin DriveTrain  \
# 114          Dodge  Viper SRT-10 convertible 2dr  Sports     USA       Rear
# 262  Mercedes-Benz                     CL600 2dr   Sedan  Europe       Rear
# 271  Mercedes-Benz         SL600 convertible 2dr  Sports  Europe       Rear
#
#          MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# 114   $81,795   $74,451         8.3       10.0         500        12
# 262  $128,420  $119,600         5.5       12.0         493        13
# 271  $126,670  $117,854         5.5       12.0         493        13
#
#      MPG_Highway  Weight  Wheelbase  Length
# 114           20    3410         99     176
# 262           19    4473        114     196
# 271           19    4429        101     179

# %%
## 7) PARA CADA MARCA ENCONTRAR EL MAYOR VALOR DE RENDIMIENTO DE GASOLINA EN CARRETERA
data.groupby("Make")["MPG_Highway"].max()
# Out:
# Make
# Acura            31
# Audi             31
# BMW              30
# Buick            30
# Cadillac         26
# Chevrolet        37
# Chrysler         30
# Dodge            36
# Ford             36
# GMC              25
# Honda            66
# Hummer           12
# Hyundai          34
# Infiniti         26
# Isuzu            21
# Jaguar           28
# Jeep             24
# Kia              33
# Land Rover       21
# Lexus            29
# Lincoln          26
# MINI             37
# Mazda            34
# Mercedes-Benz    30
# Mercury          27
# Mitsubishi       31
# Nissan           35
# Oldsmobile       32
# Pontiac          36
# Porsche          29
# Saab             30
# Saturn           35
# Scion            38
# Subaru           28
# Suzuki           31
# Toyota           51
# Volkswagen       46
# Volvo            29
# Name: MPG_Highway, dtype: int64

# %%
## 8) CREAR UNA TABLA QUE TENGA LOS REGISTROS MISSING DE CYILINDERS ##
data[data["Cylinders"].isnull()]
# Out:
#       Make               Model    Type Origin DriveTrain     MSRP  Invoice  \
# 247  Mazda  RX-8 4dr automatic  Sports   Asia       Rear  $25,700  $23,794
# 248  Mazda     RX-8 4dr manual  Sports   Asia       Rear  $27,200  $25,179
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 247         1.3        NaN         197        18           25    3053
# 248         1.3        NaN         238        18           24    3029
#
#      Wheelbase  Length
# 247        106     174
# 248        106     174

# %%
## 9)  Crear una tabla que tenga el registro con el menor gasto de gasolina en ciudad por tipo de vehículo.
data.groupby("Type")["MPG_City"].min()
# Out:
# Type
# Hybrid    46
# SUV       10
# Sedan     12
# Sports    12
# Truck     13
# Wagon     15
# Name: MPG_City, dtype: int64
